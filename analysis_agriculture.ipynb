# %%
import pandas as pd
from translation import translate_dataframe
from project.config import api_key
file_path = 'data/indices of agricultural production.csv'
data = pd.read_csv(file_path, delimiter=';', skiprows=5)

# %%
data.columns = data.iloc[0]  
data = data[1:]  
data = data.reset_index(drop=True)  
data = data.dropna(axis=1, how='all')

data
# Out:
# 0          in 2021 prices; in % to the previous year)  \
# 0                                      Роки / \nYears
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                2010
# 5                                                2011
# 6                                                2012
# 7                                                2013
# 8                                                2014
# 9                                                2015
# 10                                               2016
# 11                                               2017
# 12                                               2018
# 13                                               2019
# 14                                               2020
# 15                                               2021
# 16                                             2022 2
# 17                                             2023 2
# 18  1Дані наведено без урахування тимчасово окупов...
# 19  2  Дані за 2022-2023 рік наведено без урахуван...
#
# 0                                                 NaN  \
# 0   Господарства усіх категорій /\n All agricultur...
# 1                                                 NaN
# 2   продукція сільського господарства /\nagricultu...
# 3                                                 NaN
# 4                                                98,6
# 5                                               120,2
# 6                                                96,1
# 7                                               113,6
# 8                                               102,2
# 9                                                95,2
# 10                                              106,3
# 11                                               97,8
# 12                                              108,2
# 13                                              101,4
# 14                                               89,9
# 15                                              116,4
# 16                                               74,7
# 17                                              111,1
# 18                                                NaN
# 19                                                NaN
#
# 0                                          NaN  \
# 0                                          NaN
# 1                                          NaN
# 2                             з неї / of which
# 3   продукція рослинництва /\ncrop production
# 4                                         96,5
# 5                                        128,3
# 6                                         93,4
# 7                                        117,0
# 8                                        103,0
# 9                                         94,8
# 10                                       109,0
# 11                                        97,1
# 12                                       110,1
# 13                                       101,7
# 14                                        88,0
# 15                                       122,3
# 16                                        71,8
# 17                                       113,9
# 18                                         NaN
# 19                                         NaN
#
# 0                                             NaN  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3   продукція тваринництва / \nanimal production
# 4                                           104,4
# 5                                            99,5
# 6                                           105,0
# 7                                           103,8
# 8                                            99,5
# 9                                            96,4
# 10                                           97,2
# 11                                          100,3
# 12                                          101,2
# 13                                          100,1
# 14                                           97,6
# 15                                           95,1
# 16                                           88,2
# 17                                          100,4
# 18                                            NaN
# 19                                            NaN
#
# 0                                                 NaN  \
# 0                            У тому числі / Including
# 1                         підприємства /\nenterprises
# 2   продукція сільського господарства /\nagricultu...
# 3                                                 NaN
# 4                                                97,5
# 5                                               128,1
# 6                                                94,0
# 7                                               120,3
# 8                                               103,8
# 9                                                94,9
# 10                                              109,6
# 11                                               97,0
# 12                                              111,9
# 13                                              102,6
# 14                                               88,0
# 15                                              122,2
# 16                                               72,1
# 17                                              116,4
# 18                                                NaN
# 19                                                NaN
#
# 0                                          NaN  \
# 0                                          NaN
# 1                                          NaN
# 2                             з неї / of which
# 3   продукція рослинництва /\ncrop production
# 4                                         94,8
# 5                                        134,1
# 6                                         91,3
# 7                                        123,1
# 8                                        103,9
# 9                                         94,5
# 10                                       112,1
# 11                                        96,3
# 12                                       113,3
# 13                                       102,4
# 14                                        86,0
# 15                                       127,3
# 16                                        69,0
# 17                                       118,8
# 18                                         NaN
# 19                                         NaN
#
# 0                                             NaN  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3   продукція тваринництва / \nanimal production
# 4                                           110,0
# 5                                           104,2
# 6                                           108,3
# 7                                           108,4
# 8                                           103,3
# 9                                            96,5
# 10                                           97,4
# 11                                          101,0
# 12                                          104,5
# 13                                          103,7
# 14                                           99,5
# 15                                           97,8
# 16                                           92,0
# 17                                          105,0
# 18                                            NaN
# 19                                            NaN
#
# 0                                                 NaN  \
# 0                                                 NaN
# 1               господарства населення /\n households
# 2   продукція сільського господарства /\nagricultu...
# 3                                                 NaN
# 4                                               100,1
# 5                                               110,0
# 6                                                99,2
# 7                                               104,0
# 8                                                99,6
# 9                                                95,8
# 10                                              100,7
# 11                                               99,3
# 12                                              101,5
# 13                                               99,0
# 14                                               93,8
# 15                                              105,1
# 16                                               80,5
# 17                                              100,2
# 18                                                NaN
# 19                                                NaN
#
# 0                                          NaN  \
# 0                                          NaN
# 1                                          NaN
# 2                             з неї / of which
# 3   продукція рослинництва /\ncrop production
# 4                                         99,5
# 5                                        118,6
# 6                                         97,4
# 7                                        106,0
# 8                                        101,3
# 9                                         95,5
# 10                                       102,5
# 11                                        99,1
# 12                                       103,1
# 13                                       100,1
# 14                                        93,0
# 15                                       110,8
# 16                                        79,2
# 17                                       102,4
# 18                                         NaN
# 19                                         NaN
#
# 0                                             NaN
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3   продукція тваринництва / \nanimal production
# 4                                           100,9
# 5                                            96,5
# 6                                           102,6
# 7                                           100,2
# 8                                            96,3
# 9                                            96,3
# 10                                           97,1
# 11                                           99,6
# 12                                           98,2
# 13                                           96,6
# 14                                           95,7
# 15                                           92,3
# 16                                           83,9
# 17                                           94,8
# 18                                            NaN
# 19                                            NaN

# %%
new_column_names = [
    data.iloc[0, 0],  
    data.iloc[2, 1],  
    data.iloc[3, 2],  
    data.iloc[3, 3],  
]

data.columns = new_column_names + data.columns[4:].tolist()
data
# Out:
#                                        Роки / \nYears  \
# 0                                      Роки / \nYears
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                2010
# 5                                                2011
# 6                                                2012
# 7                                                2013
# 8                                                2014
# 9                                                2015
# 10                                               2016
# 11                                               2017
# 12                                               2018
# 13                                               2019
# 14                                               2020
# 15                                               2021
# 16                                             2022 2
# 17                                             2023 2
# 18  1Дані наведено без урахування тимчасово окупов...
# 19  2  Дані за 2022-2023 рік наведено без урахуван...
#
#    продукція сільського господарства /\nagricultural production   \
# 0   Господарства усіх категорій /\n All agricultur...
# 1                                                 NaN
# 2   продукція сільського господарства /\nagricultu...
# 3                                                 NaN
# 4                                                98,6
# 5                                               120,2
# 6                                                96,1
# 7                                               113,6
# 8                                               102,2
# 9                                                95,2
# 10                                              106,3
# 11                                               97,8
# 12                                              108,2
# 13                                              101,4
# 14                                               89,9
# 15                                              116,4
# 16                                               74,7
# 17                                              111,1
# 18                                                NaN
# 19                                                NaN
#
#     продукція рослинництва /\ncrop production   \
# 0                                          NaN
# 1                                          NaN
# 2                             з неї / of which
# 3   продукція рослинництва /\ncrop production
# 4                                         96,5
# 5                                        128,3
# 6                                         93,4
# 7                                        117,0
# 8                                        103,0
# 9                                         94,8
# 10                                       109,0
# 11                                        97,1
# 12                                       110,1
# 13                                       101,7
# 14                                        88,0
# 15                                       122,3
# 16                                        71,8
# 17                                       113,9
# 18                                         NaN
# 19                                         NaN
#
#     продукція тваринництва / \nanimal production   \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3   продукція тваринництва / \nanimal production
# 4                                           104,4
# 5                                            99,5
# 6                                           105,0
# 7                                           103,8
# 8                                            99,5
# 9                                            96,4
# 10                                           97,2
# 11                                          100,3
# 12                                          101,2
# 13                                          100,1
# 14                                           97,6
# 15                                           95,1
# 16                                           88,2
# 17                                          100,4
# 18                                            NaN
# 19                                            NaN
#
#                                                   NaN  \
# 0                            У тому числі / Including
# 1                         підприємства /\nenterprises
# 2   продукція сільського господарства /\nagricultu...
# 3                                                 NaN
# 4                                                97,5
# 5                                               128,1
# 6                                                94,0
# 7                                               120,3
# 8                                               103,8
# 9                                                94,9
# 10                                              109,6
# 11                                               97,0
# 12                                              111,9
# 13                                              102,6
# 14                                               88,0
# 15                                              122,2
# 16                                               72,1
# 17                                              116,4
# 18                                                NaN
# 19                                                NaN
#
#                                            NaN  \
# 0                                          NaN
# 1                                          NaN
# 2                             з неї / of which
# 3   продукція рослинництва /\ncrop production
# 4                                         94,8
# 5                                        134,1
# 6                                         91,3
# 7                                        123,1
# 8                                        103,9
# 9                                         94,5
# 10                                       112,1
# 11                                        96,3
# 12                                       113,3
# 13                                       102,4
# 14                                        86,0
# 15                                       127,3
# 16                                        69,0
# 17                                       118,8
# 18                                         NaN
# 19                                         NaN
#
#                                               NaN  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3   продукція тваринництва / \nanimal production
# 4                                           110,0
# 5                                           104,2
# 6                                           108,3
# 7                                           108,4
# 8                                           103,3
# 9                                            96,5
# 10                                           97,4
# 11                                          101,0
# 12                                          104,5
# 13                                          103,7
# 14                                           99,5
# 15                                           97,8
# 16                                           92,0
# 17                                          105,0
# 18                                            NaN
# 19                                            NaN
#
#                                                   NaN  \
# 0                                                 NaN
# 1               господарства населення /\n households
# 2   продукція сільського господарства /\nagricultu...
# 3                                                 NaN
# 4                                               100,1
# 5                                               110,0
# 6                                                99,2
# 7                                               104,0
# 8                                                99,6
# 9                                                95,8
# 10                                              100,7
# 11                                               99,3
# 12                                              101,5
# 13                                               99,0
# 14                                               93,8
# 15                                              105,1
# 16                                               80,5
# 17                                              100,2
# 18                                                NaN
# 19                                                NaN
#
#                                            NaN  \
# 0                                          NaN
# 1                                          NaN
# 2                             з неї / of which
# 3   продукція рослинництва /\ncrop production
# 4                                         99,5
# 5                                        118,6
# 6                                         97,4
# 7                                        106,0
# 8                                        101,3
# 9                                         95,5
# 10                                       102,5
# 11                                        99,1
# 12                                       103,1
# 13                                       100,1
# 14                                        93,0
# 15                                       110,8
# 16                                        79,2
# 17                                       102,4
# 18                                         NaN
# 19                                         NaN
#
#                                               NaN
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3   продукція тваринництва / \nanimal production
# 4                                           100,9
# 5                                            96,5
# 6                                           102,6
# 7                                           100,2
# 8                                            96,3
# 9                                            96,3
# 10                                           97,1
# 11                                           99,6
# 12                                           98,2
# 13                                           96,6
# 14                                           95,7
# 15                                           92,3
# 16                                           83,9
# 17                                           94,8
# 18                                            NaN
# 19                                            NaN

# %%
data = data.iloc[4:]
data = data.iloc[:-2]
data = data.loc[:, data.columns.notna()]
data
# Out:
#    Роки / \nYears  \
# 4            2010
# 5            2011
# 6            2012
# 7            2013
# 8            2014
# 9            2015
# 10           2016
# 11           2017
# 12           2018
# 13           2019
# 14           2020
# 15           2021
# 16         2022 2
# 17         2023 2
#
#    продукція сільського господарства /\nagricultural production   \
# 4                                                98,6
# 5                                               120,2
# 6                                                96,1
# 7                                               113,6
# 8                                               102,2
# 9                                                95,2
# 10                                              106,3
# 11                                               97,8
# 12                                              108,2
# 13                                              101,4
# 14                                               89,9
# 15                                              116,4
# 16                                               74,7
# 17                                              111,1
#
#    продукція рослинництва /\ncrop production   \
# 4                                        96,5
# 5                                       128,3
# 6                                        93,4
# 7                                       117,0
# 8                                       103,0
# 9                                        94,8
# 10                                      109,0
# 11                                       97,1
# 12                                      110,1
# 13                                      101,7
# 14                                       88,0
# 15                                      122,3
# 16                                       71,8
# 17                                      113,9
#
#    продукція тваринництва / \nanimal production
# 4                                          104,4
# 5                                           99,5
# 6                                          105,0
# 7                                          103,8
# 8                                           99,5
# 9                                           96,4
# 10                                          97,2
# 11                                         100,3
# 12                                         101,2
# 13                                         100,1
# 14                                          97,6
# 15                                          95,1
# 16                                          88,2
# 17                                         100,4

# %%
cleaned_columns = []
for col in list(data.columns):
    if '/' in col:
        cleaned_columns.append(col.split('/')[0].strip())  
    else:
        cleaned_columns.append(col)
print(cleaned_columns)
data.columns = cleaned_columns
data
# Out:
# ['Роки', 'продукція сільського господарства', 'продукція рослинництва', 'продукція тваринництва']
#       Роки продукція сільського господарства продукція рослинництва  \
# 4     2010                              98,6                   96,5
# 5     2011                             120,2                  128,3
# 6     2012                              96,1                   93,4
# 7     2013                             113,6                  117,0
# 8     2014                             102,2                  103,0
# 9     2015                              95,2                   94,8
# 10    2016                             106,3                  109,0
# 11    2017                              97,8                   97,1
# 12    2018                             108,2                  110,1
# 13    2019                             101,4                  101,7
# 14    2020                              89,9                   88,0
# 15    2021                             116,4                  122,3
# 16  2022 2                              74,7                   71,8
# 17  2023 2                             111,1                  113,9
#
#    продукція тваринництва
# 4                   104,4
# 5                    99,5
# 6                   105,0
# 7                   103,8
# 8                    99,5
# 9                    96,4
# 10                   97,2
# 11                  100,3
# 12                  101,2
# 13                  100,1
# 14                   97,6
# 15                   95,1
# 16                   88,2
# 17                  100,4

# %%
data.columns
# Out:
# Index(['Роки', 'продукція сільського господарства', 'продукція рослинництва',
#        'продукція тваринництва'],
#       dtype='object')

# %%
type(data['продукція сільського господарства'][4])
# Out:
# str

# %%
for col in data.columns:
    if col != 'Роки':
        data[col] = data[col].str.replace(',', '.').astype(float)
        
data
# Out:
#       Роки  продукція сільського господарства  продукція рослинництва  \
# 4     2010                               98.6                    96.5
# 5     2011                              120.2                   128.3
# 6     2012                               96.1                    93.4
# 7     2013                              113.6                   117.0
# 8     2014                              102.2                   103.0
# 9     2015                               95.2                    94.8
# 10    2016                              106.3                   109.0
# 11    2017                               97.8                    97.1
# 12    2018                              108.2                   110.1
# 13    2019                              101.4                   101.7
# 14    2020                               89.9                    88.0
# 15    2021                              116.4                   122.3
# 16  2022 2                               74.7                    71.8
# 17  2023 2                              111.1                   113.9
#
#     продукція тваринництва
# 4                    104.4
# 5                     99.5
# 6                    105.0
# 7                    103.8
# 8                     99.5
# 9                     96.4
# 10                    97.2
# 11                   100.3
# 12                   101.2
# 13                   100.1
# 14                    97.6
# 15                    95.1
# 16                    88.2
# 17                   100.4

# %%
type(data['продукція сільського господарства'][4])
# Out:
# numpy.float64

# %%
data['Роки'] = data['Роки'].str.split(' ').str[0]
data
# Out:
#     Роки  продукція сільського господарства  продукція рослинництва  \
# 4   2010                               98.6                    96.5
# 5   2011                              120.2                   128.3
# 6   2012                               96.1                    93.4
# 7   2013                              113.6                   117.0
# 8   2014                              102.2                   103.0
# 9   2015                               95.2                    94.8
# 10  2016                              106.3                   109.0
# 11  2017                               97.8                    97.1
# 12  2018                              108.2                   110.1
# 13  2019                              101.4                   101.7
# 14  2020                               89.9                    88.0
# 15  2021                              116.4                   122.3
# 16  2022                               74.7                    71.8
# 17  2023                              111.1                   113.9
#
#     продукція тваринництва
# 4                    104.4
# 5                     99.5
# 6                    105.0
# 7                    103.8
# 8                     99.5
# 9                     96.4
# 10                    97.2
# 11                   100.3
# 12                   101.2
# 13                   100.1
# 14                    97.6
# 15                    95.1
# 16                    88.2
# 17                   100.4

# %%
data_translated = translate_dataframe(data, api_key)
data_translated
# Out:
#    Years  agricultural products  crop production  livestock products
# 4   2010                   98.6             96.5               104.4
# 5   2011                  120.2            128.3                99.5
# 6   2012                   96.1             93.4               105.0
# 7   2013                  113.6            117.0               103.8
# 8   2014                  102.2            103.0                99.5
# 9   2015                   95.2             94.8                96.4
# 10  2016                  106.3            109.0                97.2
# 11  2017                   97.8             97.1               100.3
# 12  2018                  108.2            110.1               101.2
# 13  2019                  101.4            101.7               100.1
# 14  2020                   89.9             88.0                97.6
# 15  2021                  116.4            122.3                95.1
# 16  2022                   74.7             71.8                88.2
# 17  2023                  111.1            113.9               100.4

# %%
import matplotlib.pyplot as plt

data_translated.set_index('Years', inplace=True)

data_translated.plot(figsize=(10, 6), marker = 'o')

plt.xlabel('Years')
plt.ylabel('Values')
plt.title('Progression Over Years of Indices of agricultural production')
plt.legend(title='Columns', loc='upper left', bbox_to_anchor=(0, 1))
plt.grid(True)
plt.tight_layout()
plt.show()
